# %% [markdown]
# <a href="https://colab.research.google.com/github/0ginny/TIL/blob/main/240326_titanic_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 구글 코랩 및 드라이브 사용

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive") #구글 드라이브 사용
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/Udemy_Machinelearning_Basic # 현재 파일 위치로 이동
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Colab Notebooks/Udemy_Machinelearning_Basic # 현재 파일 위치로 이동'
# /content

# %% [markdown]
# ### 구글 파일 업로드

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a8d0a60-db0a-4b0c-b4e6-31127789fffe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a8d0a60-db0a-4b0c-b4e6-31127789fffe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import io

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 타이타닉 데이터 분석

# %% [markdown]
# ### 데이터 저장

# %%
df = pd.read_csv(io.StringIO(uploaded['train.csv'].decode('utf-8')))
train = df
print(train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df0 = pd.read_csv(io.StringIO(uploaded['test.csv'].decode('utf-8')))

test = df0
print(test)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# 처리해야할 것
"""
- 결측치
- 성별 (좀 쉽게)
- 이름(좀 쉽게)
"""
# Out:
# '\n- 결측치\n- 성별 (좀 쉽게)\n- 이름(좀 쉽게)\n'

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
train.columns # train data feature 확인
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.isnull(train).sum() # 결측치 확인
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(pd.isnull(test).sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### 데이터 시각화

# %%
sns.set()

# %%
def pivot(feature) :
    pclass_pibot = train.pivot_table(index = [feature],values = "Survived")
    pclass_pibot.plot.bar()
    plt.show()

# %%
pivot('Sex')

# %%
pivot('SibSp')

# %%
pivot('Pclass')

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 이름 처리

# %%
# 데이터 합치기
train_test_data = [train,test]
train_test_data
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
for dataset in train_test_data : # 이름에서 성별 확인 가능 단어 추출
    dataset["Title"] = dataset['Name'].str.extract('([A-za-z]+)\. ', expand=False)

# %%
test['Title'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Mr
# 1         Mrs
# 2          Mr
# 3          Mr
# 4         Mrs
#         ...
# 413        Mr
# 414      Dona
# 415        Mr
# 416        Mr
# 417    Master
# Name: Title, Length: 418, dtype: object>

# %%
print(train['Title'])
# Out:
# 0      0.0
# 1      2.0
# 2      1.0
# 3      2.0
# 4      0.0
#       ...
# 886    3.0
# 887    1.0
# 888    1.0
# 889    0.0
# 890    0.0
# Name: Title, Length: 891, dtype: float64

# %%
title_mapping = {"Mr"  : 0 , "Miss" : 1, "Mrs" : 2, "Master" : 3 , "Dr" : 3 , "Rev" : 3 , "Col" : 3, "Ms" : 2, "Mile" : 3, "Major": 3 , "Lady" : 3, "Capt": 3,
                 "Sir": 3, "Don": 3, "Mme" : 3, "jonkheer" : 3, "Countess" :3}
for dataset in train_test_data:
    dataset["Title"] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title  Titlte
# 0      0         A/5 21171   7.2500   NaN        S    0.0     0.0
# 1      0          PC 17599  71.2833   C85        C    2.0     2.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    1.0     1.0
# ...

# %%
print(pd.isnull(train).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Title            0
# Titlte           3
# dtype: int64

# %%
print(pd.isnull(test).sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Title            0
# Titlte           1
# dtype: int64

# %%
test['Title'].fillna(df["Title"].mean(),inplace = True) #평균값으로 채우기

# %%
train['Title'].fillna(df["Title"].mean(),inplace = True) #평균값으로 채우기

# %% [markdown]
# ### 나이 처리

# %%
df1 = train
df1['Age'].fillna(df1['Age'].median(), inplace= True)

df2 = test
df2['Age'].fillna(df1['Age'].median(), inplace= True)

#결측치 중위값으로 처리

# %%
train['Age'].isnull().sum()
# Out:
# 0

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'] = train["Embarked"].fillna("S") #빈값들 S로 넣기

# %%
train['Embarked'][train['Embarked'] == "S"] = 0
train['Embarked'][train['Embarked'] == "C"] = 1
train['Embarked'][train['Embarked'] == "Q"] = 2

test['Embarked'][test['Embarked'] == "S"] = 0
test['Embarked'][test['Embarked'] == "C"] = 1
test['Embarked'][test['Embarked'] == "Q"] = 2
#매핑시키기
# Out:
# <ipython-input-58-736c312f7804>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Embarked'][train['Embarked'] == "S"] = 0
# <ipython-input-58-736c312f7804>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Embarked'][train['Embarked'] == "C"] = 1
# <ipython-input-58-736c312f7804>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Embarked'][train['Embarked'] == "Q"] = 2
# ...

# %%
train['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Fare 처리

# %%
test['Fare'].fillna(df['Fare'].mean(), inplace=True)
train['Fare'].fillna(df['Fare'].mean(), inplace=True)

# %% [markdown]
# ### 성별 맵핑

# %%
sex_mapping = {'male' : 0, 'female' : 1}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

# %% [markdown]
# ### 필용없는 데이터 처리

# %%
train = train.drop(['Name'], axis =1)
train = train.drop(['PassengerId'], axis =1)
train = train.drop(['Titlte'], axis =1)
train = train.drop(['Cabin'], axis =1)
train = train.drop(['Ticket'], axis =1)

test = test.drop(['Name'], axis =1)
test = test.drop(['PassengerId'], axis =1)
test = test.drop(['Titlte'], axis =1)
test = test.drop(['Cabin'], axis =1)
test = test.drop(['Ticket'], axis =1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        0    0.0
# 1         1       1    1  38.0      1      0  71.2833        1    2.0
# 2         1       3    1  26.0      0      0   7.9250        0    1.0
# 3         1       1    1  35.0      1      0  53.1000        0    2.0
# 4         0       3    0  35.0      0      0   8.0500        0    0.0

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Title       0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Title       0
# dtype: int64

# %% [markdown]
# ## 머신러닝

# %%
# 데이터 분할
pred = train.drop(['Survived'], axis = 1)
target = train["Survived"]

# 예측 목적이 Survivved
x_train,x_test,y_train,y_test = train_test_split(pred,target,test_size = 0.3)

# %% [markdown]
# ### 로지스틱 회귀

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

logr = LogisticRegression()
logr.fit(x_train,y_train)
y_pred = logr.predict(x_test)
acc_logr = round(accuracy_score(y_pred,y_test) * 100 , 2)
acc_logr
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 79.48

# %% [markdown]
# # 의사결정 나무

# %%
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_test)
acc_decision = round(accuracy_score(y_pred,y_test) * 100 , 2)
acc_decision
# Out:
# 69.4

# %% [markdown]
# ### 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_test)
acc_randomforest = round(accuracy_score(y_pred,y_test) * 100 , 2)
acc_randomforest
# Out:
# 76.87

# %% [markdown]
# ### knn

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
acc_knn = round(accuracy_score(y_pred,y_test) * 100 , 2)
acc_knn
# Out:
# 67.16

# %%
models = pd.DataFrame({
    'Model'  :['Logistic Regression', 'Decision Tree', 'RamdomForeset', 'KNN'],
    'Score' : [acc_logr,acc_decision,acc_randomforest,acc_knn]
})

# %%
models.sort_values(by='Score', ascending = False)
# Out:
#                  Model  Score
# 0  Logistic Regression  79.48
# 2        RamdomForeset  76.87
# 1        Decision Tree  69.40
# 3                  KNN  67.16
